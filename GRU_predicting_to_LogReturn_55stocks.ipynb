# %%
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout
from tensorflow.keras.layers import LeakyReLU
from keras.initializers import RandomNormal
import numpy as np
import pandas as pd

# %%
sectors_data = {}
excel_file_path = 'logreturns_2000_2020_data_by_sector.xlsx'
snp_price_data = pd.ExcelFile(excel_file_path)
for sheet_name in snp_price_data.sheet_names:
    sheet_data = pd.read_excel(excel_file_path, sheet_name=sheet_name)
    sheet_data['Date'] = pd.to_datetime(sheet_data['Unnamed: 0'], format='%Y-%m-%d')
    sheet_data.set_index('Date', inplace=True)
    sheet_data.drop(columns='Unnamed: 0', inplace=True)
    sectors_data[sheet_name] = sheet_data

# 데이터프레임 생성
df = pd.DataFrame()
for sector, data in sectors_data.items():
    data.columns = [f"{sector}_{col}" for col in data.columns]
    if df.empty:
        df = data
    else:
        df = df.join(data, how='outer')

df = df[1:]

# %%
#스케일링을 위한 학습데이터와 테스트데이터 셋 분리
train_scaling_size = int(len(df) * 0.7)
t_train_X = df[0 : train_scaling_size]
t_train_y = df[0 : train_scaling_size]


# 전체 데이터 중 최소값과 최대값 구하기
tot_train_min = np.minimum.reduce([t_train_X.min(axis=0), t_train_X.min(axis=0)])
tot_train_max = np.maximum.reduce([t_train_X.max(axis=0), t_train_X.max(axis=0)])

# 각 주식의 범위를 계산
train_range = tot_train_max - tot_train_min

# %%
import pandas as pd

end_date = pd.Timestamp('2020-12-31')
one_month = pd.DateOffset(months=1)
sixty_days = pd.DateOffset(days=60)

data_X = []
data_y = []
start_day_idx = [] # data_X를 생성하기 위한 매달 시작일 인덱스 리스트

# data_y부터 생성
start_date = pd.Timestamp('2000-04-01')

while start_date < end_date:
    end_of_period = start_date + pd.DateOffset(months=1) - pd.DateOffset(days=1)
    selected_data = df[(df.index >= start_date) & (df.index <= end_of_period)]

    indexing = df.index.get_loc(selected_data.index[0])

    # 각 주식에 대한 월별 평균 수익률 계산
    average_values = selected_data.mean(axis=0)

    data_y.append(average_values)
    start_day_idx.append(indexing)
    start_date = start_date + pd.DateOffset(months=1)  # Move to next month

start_date = pd.Timestamp('2000-01-01')

i = 0
while i < len(data_y):
    index_day_start = start_day_idx[i]

    nearest_index = None
    for j in range(index_day_start - 1, index_day_start - 61, -1):
        if j < 0:
            break
        if df.index[j] in df.index:
            nearest_index = j
            break

    if nearest_index is not None:
        sixty_day_data = df.iloc[nearest_index - 60 : nearest_index]
        data_X.append(sixty_day_data)
    else:
        pass

    i += 1

# %%
#학습데이터와 테스트데이터 셋 분리
train_size = int(len(data_y) * 0.7)
train_X = np.array(data_X[0 : train_size])
train_y = np.array(data_y[0 : train_size])

# # test_size = len(data_y) - train_size
# test_X = np.array(data_X[train_size : len(data_X)])
# test_y = np.array(data_y[train_size : len(data_y)])

#테스트데이터는 전체 데이터로~
test_X = np.array(data_X)
test_y = np.array(data_y)

print('훈련 데이터의 크기 :', train_X.shape, train_y.shape)
print('테스트 데이터의 크기 :', test_X.shape, test_y.shape)
# Out:
# 훈련 데이터의 크기 : (174, 60, 55) (174, 55)
# 테스트 데이터의 크기 : (249, 60, 55) (249, 55)

# %%
# 스케일링
train_X = (train_X - tot_train_min) / (train_range + 1e-7)
train_y = (train_y - tot_train_min) / (train_range + 1e-7)
test_X = (test_X - tot_train_min) / (train_range + 1e-7)
test_y = (test_y - tot_train_min) / (train_range + 1e-7)

# %%
test_X = np.reshape(test_X, (-1, 60, 55))

# %%
def GRU_model_regularization(X_train, y_train, X_test):
    """
    create a GRU model trained on X_train and y_train
    and make predictions on the X_test data
    """
    # create a model
    # The GRU architecture
    my_GRU_model = Sequential()
    my_GRU_model.add(GRU(units = 50, return_sequences = True, input_shape = (60, 55)))
    my_GRU_model.add(LeakyReLU())
    my_GRU_model.add(GRU(units = 50))
    my_GRU_model.add(LeakyReLU())
    my_GRU_model.add(Dropout(0.2))
    my_GRU_model.add(Dense(units = 55))


    # Compiling the RNN
    my_GRU_model.compile(optimizer = 'adam', loss = 'mean_squared_error')

    # Fitting to the trainig set
    my_GRU_model.fit(X_train, y_train, epochs = 400, batch_size = 128, verbose = 1)

    # Predicting on test sets
    GRU_prediction = my_GRU_model.predict(X_test)

    return my_GRU_model, GRU_prediction

# %%
my_GRU_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_6 (GRU)                 (None, 60, 50)            16050
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 60, 50)            0
#
#  gru_7 (GRU)                 (None, 50)                15300
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 50)                0
#
#  dropout_4 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 55)                2805
#
# =================================================================
# Total params: 34155 (133.42 KB)
# Trainable params: 34155 (133.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
my_GRU_model,GRU_prediction = GRU_model_regularization(train_X, train_y, test_X)
# Out:
# Epoch 1/400
# 2/2 [==============================] - 4s 109ms/step - loss: 0.3056
# Epoch 2/400
# 2/2 [==============================] - 0s 107ms/step - loss: 0.2580
# Epoch 3/400
# 2/2 [==============================] - 0s 110ms/step - loss: 0.2178
# Epoch 4/400
# 2/2 [==============================] - 0s 99ms/step - loss: 0.1879
# Epoch 5/400
# 2/2 [==============================] - 0s 109ms/step - loss: 0.1621
# Epoch 6/400
# 2/2 [==============================] - 0s 109ms/step - loss: 0.1394
# Epoch 7/400
# 2/2 [==============================] - 0s 108ms/step - loss: 0.1200
# Epoch 8/400
# 2/2 [==============================] - 0s 107ms/step - loss: 0.1049
# Epoch 9/400
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0880
# Epoch 10/400
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0785
# Epoch 11/400
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0667
# Epoch 12/400
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0603
# Epoch 13/400
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0538
# Epoch 14/400
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0459
# Epoch 15/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0409
# Epoch 16/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0372
# Epoch 17/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0357
# Epoch 18/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0315
# Epoch 19/400
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0309
# Epoch 20/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0288
# Epoch 21/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0252
# Epoch 22/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0257
# Epoch 23/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0252
# Epoch 24/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0259
# Epoch 25/400
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0222
# Epoch 26/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0207
# Epoch 27/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0221
# Epoch 28/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0198
# Epoch 29/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0193
# Epoch 30/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0199
# Epoch 31/400
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0177
# Epoch 32/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0186
# Epoch 33/400
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0176
# Epoch 34/400
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0182
# Epoch 35/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0167
# Epoch 36/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0175
# Epoch 37/400
# 2/2 [==============================] - 0s 89ms/step - loss: 0.0157
# Epoch 38/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0155
# Epoch 39/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0155
# Epoch 40/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0149
# Epoch 41/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0140
# Epoch 42/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0144
# Epoch 43/400
# 2/2 [==============================] - 0s 85ms/step - loss: 0.
400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0053
# Epoch 164/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0050
# Epoch 165/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0050
# Epoch 166/400
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0047
# Epoch 167/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0045
# Epoch 168/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0047
# Epoch 169/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0047
# Epoch 170/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0049
# Epoch 171/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0046
# Epoch 172/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0048
# Epoch 173/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0047
# Epoch 174/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0047
# Epoch 175/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0045
# Epoch 176/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0042
# Epoch 177/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0046
# Epoch 178/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0040
# Epoch 179/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0042
# Epoch 180/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0047
# Epoch 181/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0041
# Epoch 182/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0046
# Epoch 183/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0043
# Epoch 184/400
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0046
# Epoch 185/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0042
# Epoch 186/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0047
# Epoch 187/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0040
# Epoch 188/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0042
# Epoch 189/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0038
# Epoch 190/400
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0041
# Epoch 191/400
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0040
# Epoch 192/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0042
# Epoch 193/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0044
# Epoch 194/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0039
# Epoch 195/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0042
# Epoch 196/400
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0043
# Epoch 197/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0038
# Epoch 198/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0045
# Epoch 199/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0043
# Epoch 200/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0043
# Epoch 201/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0037
# Epoch 202/400
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0045
# Epoch 203/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0039
# Epoch 204/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0042
# Epoch 205/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0041
# Epoch 206/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0040
# Epoch 207/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0038
# Epoch 208/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0040
# Epoch 209/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0039
# Epoch 210/400
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0040
# Epoch 211/400
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0037
# Epoch 212/400
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0040
# Epoch 213/400
# 2/2 [==============================] - 0s 131ms/step - loss: 0.0036
# Epoch 214/400
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0037
# Epoch 215/400
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0039
# Epoch 216/400
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0039
# Epoch 217/400
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0039
# Epoch 218/400
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0036
# Epoch 219/400
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0038
# Epoch 220/400
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0040
# Epoch 221/400
# 2/2 [==============================] - 0s 259ms/step - loss: 0.0040
# Epoch 222/400
# 2/2 [==============================] - 1s 299ms/step - loss: 0.0037
# Epoch 223/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0034
# Epoch 224/400
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0037
# Epoch 225/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0039
# Epoch 226/400
# 2/2 [==============================] - 1s 202ms/step - loss: 0.0037
# Epoch 227/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0035
# Epoch 228/400
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0039
# Epoch 229/400
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0039
# Epoch 230/400
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0040
# Epoch 231/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0035
# Epoch 232/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0038
# Epoch 233/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0036
# Epoch 234/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0038
# Epoch 235/400
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0046
# Epoch 236/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0033
# Epoch 237/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0036
# Epoch 238/400
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0033
# Epoch 239/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0038
# Epoch 240/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0035
# Epoch 241/400
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0037
# Epoch 242/400
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0037
# Epoch 243/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0031
# Epoch 244/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0034
# Epoch 245/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0033
# Epoch 246/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0030
# Epoch 247/400
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0035
# Epoch 248/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0035
# Epoch 249/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0034
# Epoch 250/400
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0035
# Epoch 251/400
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0033
# Epoch 252/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0031
# Epoch 253/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0035
# Epoch 254/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0036
# Epoch 255/400
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0033
# Epoch 256/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0037
# Epoch 257/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0033
# Epoch 258/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0032
# Epoch 259/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0033
# Epoch 260/400
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0032
# Epoch 261/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0034
# Epoch 262/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0030
# Epoch 263/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0030
# Epoch 264/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0031
# Epoch 265/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0035
# Epoch 266/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0030
# Epoch 267/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0032
# Epoch 268/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0034
# Epoch 269/400
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0031
# Epoch 270/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0034
# Epoch 271/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0037
# Epoch 272/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0031
# Epoch 273/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0033
# Epoch 274/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0028
# Epoch 275/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0034
# Epoch 276/400
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0031
# Epoch 277/400
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0032
# Epoch 278/400
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0032
# Epoch 279/400
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0036
# Epoch 280/400
# 2/2 [==============================] - 0s 117ms/step - loss: 0.
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0024
# 3/3 [==============================] - 1s 16ms/step

# %%
GRU_prediction = my_GRU_model.predict(test_X)
# Out:
# 8/8 [==============================] - 0s 28ms/step

# %%
test_y = test_y * (train_range + 1e-7) + tot_train_min
pred_y = GRU_prediction * (train_range + 1e-7) + tot_train_min

# %%
# Assuming predictions is a NumPy array
column_names = [f'Prediction_{i}' for i in range(pred_y.shape[1])]
predictions_df = pd.DataFrame(pred_y, columns=column_names)

# Save predictions to an Excel file
predictions_df.to_excel('model_predictions_logreturns.xlsx', index=False)

# %%
import matplotlib.pyplot as plt

stocks = {
        'Tele' : ['VZ', 'DIS', 'T', 'CMCSA', 'EA'],
        'COND' : ['AMZN', 'HD', 'MCD', 'NKE', 'SBUX'],
        'ENRG': ['XOM', 'CVX', 'COP', 'EOG', 'SLB'],
        'HLCA' : ['JNJ', 'PFE', 'UNH','MRK','ABT'],
        'INDS' : ['BA', 'MMM','UNP','HON','RTX'],
        'MTRS': ['PPG', 'APD', 'ECL', 'SHW', 'NEM'],
        'FINC' : ['JPM', 'BRK-B', 'BAC', 'WFC', 'C'],
        'CONS' : ['PG', 'KO', 'PEP','WMT','MO'],
        'INFT' : ['AAPL','MSFT','INTC','CSCO','ORCL'],
        'UTIL' : ['NEE','DUK','D','SO','EXC'],
        'REES' : ['AMT', 'SPG', 'CCI', 'PLD', 'PSA']
    }



# 각 주식에 대한 그래프 그리기 위해 회사 리스트 생성
company_list = []
for sector in stocks:
    company_list += stocks[sector]

plt.rcParams['font.size'] = 20

# 각 주식 별 예측값&실제값 그래프 그리기
for i, company in enumerate(company_list):
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    plt.plot(test_y[:,i], color='blue', label='Actual Stock Price of ' + company)

    # 예측 데이터 그래프
    plt.plot(pred_y[:,i], color='red', label='Predicted Stock Price of ' + company)

    plt.title('Stock Price Prediction of ' + company)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 각 섹터별 예측값&실제값 그래프 그리기

plt.rcParams['font.size'] = 20

for sector in stocks:
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    avg_test_y = np.mean([test_y[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_test_y, color='blue', label='Average Real Stock Price of ' + sector)

    # 예측 데이터 그래프
    avg_pred_y = np.mean([pred_y[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price of ' + sector)

    plt.title('Average Stock Price Prediction of ' + sector, fontsize=36)
    plt.xlabel('Time', fontsize=36)
    plt.ylabel('Stock Price', fontsize=36)
    plt.legend()
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 모든 주식의 평균 예측값& 실제값 그래프 그리기

plt.rcParams['font.size'] = 20

plt.figure(figsize=(20,10))

# 실제 데이터 그래프
avg_test_y = np.mean(test_y, axis=1)
plt.plot(avg_test_y, color='blue', label='Average Real Stock Price')

# 예측 데이터 그래프
avg_pred_y = np.mean(pred_y, axis=1)
plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price')

plt.title('Average Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
