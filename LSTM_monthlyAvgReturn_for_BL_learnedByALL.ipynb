# %%
import numpy as np
import pandas as pd

sectors_data = {}
excel_file_path = 'stocks_2000_2020_data_by_sector.xlsx'
snp_price_data = pd.ExcelFile(excel_file_path)
for sheet_name in snp_price_data.sheet_names:
    sheet_data = pd.read_excel(excel_file_path, sheet_name=sheet_name)
    sheet_data['Date'] = pd.to_datetime(sheet_data['Unnamed: 0'], format='%Y-%m-%d')
    sheet_data.set_index('Date', inplace=True)
    sheet_data.drop(columns='Unnamed: 0', inplace=True)
    sectors_data[sheet_name] = sheet_data

# 데이터프레임 생성
df = pd.DataFrame()
for sector, data in sectors_data.items():
    data.columns = [f"{sector}_{col}" for col in data.columns]
    if df.empty:
        df = data
    else:
        df = df.join(data, how='outer')

# %%
# 전체 데이터 중 최소값과 최대값 구하기
tot_train_min = np.minimum.reduce([df.min(axis=0), df.min(axis=0)])
tot_train_max = np.maximum.reduce([df.max(axis=0), df.max(axis=0)])

# 각 주식의 범위를 계산
train_range = tot_train_max - tot_train_min

# %%
import pandas as pd

end_date = pd.Timestamp('2020-12-31')
one_month = pd.DateOffset(months=1)
sixty_days = pd.DateOffset(days=60)

data_X = []
data_y = []
start_day_idx = [] # data_X를 생성하기 위한 매달 시작일 인덱스 리스트

# data_y부터 생성
start_date = pd.Timestamp('2000-04-01')

while start_date < end_date:
    end_of_period = start_date + pd.DateOffset(months=1) - pd.DateOffset(days=1)
    selected_data = df[(df.index >= start_date) & (df.index <= end_of_period)]

    indexing = df.index.get_loc(selected_data.index[0])

    # 각 주식에 대한 월별 평균 수익률 계산
    average_values = selected_data.mean(axis=0)

    data_y.append(average_values)
    start_day_idx.append(indexing)
    start_date = start_date + pd.DateOffset(months=1)  # Move to next month

start_date = pd.Timestamp('2000-01-01')

i = 0
while i < len(data_y):
    index_day_start = start_day_idx[i]

    nearest_index = None
    for j in range(index_day_start, index_day_start - 60, -1):
        if j < 0:
            break
        if df.index[j] in df.index:
            nearest_index = j
            break

    if nearest_index is not None:
        sixty_day_data = df.iloc[nearest_index - 60 : nearest_index]
        data_X.append(sixty_day_data)
    else:
        pass

    i += 1

# %%
# 모델에 넣기 위해 list에서 array로 변환
data_X = np.array(data_X)
data_y = np.array(data_y)
print('훈련 데이터의 크기 :', data_X.shape, data_y.shape)
# Out:
# 훈련 데이터의 크기 : (249, 60, 55) (249, 55)

# %%
# 스케일링
_data_X = (data_X - tot_train_min) / (train_range + 1e-7)
_data_y = (data_y - tot_train_min) / (train_range + 1e-7)

# %%
# 모델 준비 // 은닉층 개수, 활성화함수 결정
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

model = Sequential()
model.add(LSTM(units=20, activation='relu', return_sequences=True, input_shape=(60, 55)))
model.add(Dropout(0.1))
model.add(LSTM(units=20, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=55))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 20)            6080
#
#  dropout (Dropout)           (None, 60, 20)            0
#
#  lstm_1 (LSTM)               (None, 20)                3280
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense (Dense)               (None, 55)                1155
#
# =================================================================
# Total params: 10515 (41.07 KB)
# Trainable params: 10515 (41.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 옵티마이저와 손실함수 결정 및 학습 실행
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(_data_X, _data_y, epochs=400, batch_size=64)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 3s 45ms/step - loss: 0.1944
# Epoch 2/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1772
# Epoch 3/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1704
# Epoch 4/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1641
# Epoch 5/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1547
# Epoch 6/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1443
# Epoch 7/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1319
# Epoch 8/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1208
# Epoch 9/400
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1103
# Epoch 10/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0998
# Epoch 11/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0912
# Epoch 12/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0826
# Epoch 13/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0756
# Epoch 14/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0678
# Epoch 15/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0634
# Epoch 16/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0569
# Epoch 17/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0529
# Epoch 18/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0479
# Epoch 19/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0464
# Epoch 20/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0427
# Epoch 21/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0398
# Epoch 22/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0381
# Epoch 23/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0366
# Epoch 24/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0354
# Epoch 25/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0344
# Epoch 26/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0316
# Epoch 27/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0308
# Epoch 28/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0294
# Epoch 29/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0304
# Epoch 30/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0292
# Epoch 31/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0297
# Epoch 32/400
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0278
# Epoch 33/400
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0269
# Epoch 34/400
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0265
# Epoch 35/400
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0259
# Epoch 36/400
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0263
# Epoch 37/400
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0260
# Epoch 38/400
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0245
# Epoch 39/400
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0246
# Epoch 40/400
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0224
# Epoch 41/400
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0228
# Epoch 42/400
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0217
# Epoch 43/400
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0227
# Epoch 44/400
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0214
# Epoch 45/400
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0203
# Epoch 46/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0200
# Epoch 47/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0192
# Epoch 48/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0201
# Epoch 49/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0176
# Epoch 50/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0180
# Epoch 51/400
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0188
# Epoch 52/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0178
# Epoch 53/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0188
# Epoch 54/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0168
# Epoch 55/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0171
# Epoch 56/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0172
# Epoch 57/400
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0160
# Epoch 58/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0150
# Epoch 59/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0155
# Epoch 60/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0167
# Epoch 61/400
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0153
# Epoch 62/400
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0164
# Epoch 63/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0153
# Epoch 64/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0145
# Epoch 65/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0149
# Epoch 66/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0144
# Epoch 67/400
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0145
# Epoch 68/400
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0148
# Epoch 69/400
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0135
# Epoch 70/400
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0151
# Epoch 71/400
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0144
# Epoch 72/400
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0134
# Epoch 73/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0143
# Epoch 74/400
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0138
# Epoch 75/400
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0149
# Epoch 76/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0148
# Epoch 77/400
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0142
# Epoch 78/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0141
# Epoch 79/400
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0137
# Epoch 80/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0126
# Epoch 81/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0128
# Epoch 82/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0128
# Epoch 83/400
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0132
# Epoch 84/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0118
# Epoch 85/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0130
# Epoch 86/400
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0118
# Epoch 87/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0121
# Epoch 88/400
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0134
# Epoch 89/400
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0122
# Epoch 90/400
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0118
# Epoch 91/400
# 4/4 [==============================] - 0s 90ms/step - loss: 0.0140
# Epoch 92/400
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0123
# Epoch 93/400
# 4/4 [==============================] - 1s 157ms/step - loss: 0.0121
# Epoch 94/400
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0118
# Epoch 95/400
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0117
# Epoch 96/400
# 4/4 [==============================] - 0s 93ms/step - loss: 0.0121
# Epoch 97/400
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0114
# Epoch 98/400
# 4/4 [==============================] - 0s 101ms/step - loss: 0.0118
# Epoch 99/400
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0109
# Epoch 100/400
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0116
# Epoch 101/400
# 4/4 [==============================] - 0s 94ms/step - loss: 0.0118
# Epoch 102/400
# 4/4 [==============================] - 1s 124ms/step - loss: 0.0129
# Epoch 103/400
# 4/4 [==============================] - 0s 102ms/step - loss: 0.0118
# Epoch 104/400
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0114
# Epoch 105/400
# 4/4 [==============================] - 0s 97ms/step - loss: 0.0113
# Epoch 106/400
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0112
# Epoch 107/400
# 4/4 [==============================] - 0s 97ms/step - loss: 0.0104
# Epoch 108/400
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0108
# Epoch 109/400
# 4/4 [==============================] - 0s 97ms/step - loss: 0.0112
# Epoch 110/400
# 4/4 [==============================] - 0s 100ms/step - loss: 0.0099
# Epoch 111/400
# 4/4 [==============================] - 0s 97ms/step - loss: 0.0113
# Epoch 112/400
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0108
# Epoch 113/400
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0114
# Epoch 114/400
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0101
# Epoch 115/400
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0096
# Epoch 116/400
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0098
# Epoch 117/400
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0100
# Epoch 118/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0101
# Epoch 119/400
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0106
# Epoch 120/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0096
# Epoch 121/400
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0103
# Epoch 122/400
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0106
# Epoch 123/400
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0098
# Epoch 124/400
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0103
# Epoch 125/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0103
# Epoch 126/400
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0104
# Epoch 127/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0111
# Epoch 128/400
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0110
# Epoch 129/400
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0101
# Epoch 130/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0102
# Epoch 131/400
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0097
# Epoch 132/400
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0093
# Epoch 133/400
# 4/4 [==============================] - 0s 91ms/step - loss: 0.0099
# Epoch 134/400
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0096
# Epoch 135/400
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0087
# Epoch 136/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0090
# Epoch 137/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0104
# Epoch 138/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0095
# Epoch 139/400
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0092
# Epoch 140/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0091
# Epoch 141/400
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0092
# Epoch 142/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0089
# Epoch 143/400
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0096
# Epoch 144/400
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0090
# Epoch 145/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0094
# Epoch 146/400
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0094
# Epoch 147/400
# 4/4 [==============================] - 0s 77ms/step - loss: 0.0090
# Epoch 148/400
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0096
# Epoch 149/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0088
# Epoch 150/400
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0100
# Epoch 151/400
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0099
# Epoch 152/400
# 4/4 [==============================] - 0s 100ms/step - loss: 0.0099
# Epoch 153/400
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0088
# Epoch 154/400
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0101
# Epoch 155/400
# 4/4 [==============================] - 0s 97ms/step - loss: 0.0090
# Epoch 156/400
# 4/4 [==============================] - 1s 163ms/step - loss: 0.0083
# Epoch 157/400
# 4/4 [==============================] - 1s 160ms/step - loss: 0.0092
# Epoch 158/400
# 4/4 [==============================] - 0s 124ms/step - loss: 0.0088
# Epoch 159/400
# 4/4 [==============================] - 1s 161ms/step - loss: 0.0087
# Epoch 160/400
# 4/4 [==============================] - 1s 174ms/step - loss: 0.0084
# Epoch 161/400
# 4/4 [==============================] - 0s 102ms/step - loss: 0.0090
# Epoch 162/400
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0101
# Epoch 163/400
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0097
# Epoch 164/400
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0087
# Epoch 165/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0083
# Epoch 166/400
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0089
# Epoch 167/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0081
# Epoch 168/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0087
# Epoch 169/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0084
# Epoch 170/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0083
# Epoch 171/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0081
# Epoch 172/400
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0080
# Epoch 173/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0076
# Epoch 174/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0084
# Epoch 175/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0086
# Epoch 176/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0078
# Epoch 177/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0086
# Epoch 178/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0087
# Epoch 179/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0092
# Epoch 180/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0103
# Epoch 181/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0087
# Epoch 182/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0090
# Epoch 183/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0083
# Epoch 184/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0092
# Epoch 185/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0079
# Epoch 186/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0082
# Epoch 187/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0092
# Epoch 188/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0079
# Epoch 189/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0083
# Epoch 190/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0091
# Epoch 191/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0077
# Epoch 192/400
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0080
# Epoch 193/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0084
# Epoch 194/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0074
# Epoch 195/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0073
# Epoch 196/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0081
# Epoch 197/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0081
# Epoch 198/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0079
# Epoch 199/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0078
# Epoch 200/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0076
# Epoch 201/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0074
# Epoch 202/400
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0088
# Epoch 203/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0081
# Epoch 204/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0080
# Epoch 205/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0073
# Epoch 206/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0080
# Epoch 207/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0076
# Epoch 208/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0078
# Epoch 209/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0073
# Epoch 210/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0075
# Epoch 211/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0081
# Epoch 212/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0077
# Epoch 213/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0073
# Epoch 214/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0073
# Epoch 215/400
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0086
# Epoch 216/400
# 4/4 [==============================] - 0s 77ms/step - loss: 0.0080
# Epoch 217/400
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0079
# Epoch 218/400
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0082
# Epoch 219/400
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0069
# Epoch 220/400
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0075
# Epoch 221/400
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0078
# Epoch 222/400
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0076
# Epoch 223/400
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0072
# Epoch 224/400
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0086
# Epoch 225/400
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0088
# Epoch 226/400
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0072
# Epoch 227/400
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0073
# Epoch 228/400
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0074
# Epoch 229/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0064
# Epoch 230/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0072
# Epoch 231/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0077
# Epoch 232/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0079
# Epoch 233/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0079
# Epoch 234/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0072
# Epoch 235/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0071
# Epoch 236/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0075
# Epoch 237/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0077
# Epoch 238/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0065
# Epoch 239/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0068
# Epoch 240/400
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0067
# Epoch 241/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0077
# Epoch 242/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0068
# Epoch 243/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0068
# Epoch 244/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0077
# Epoch 245/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0070
# Epoch 246/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0068
# Epoch 247/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0068
# Epoch 248/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0065
# Epoch 249/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0067
# Epoch 250/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0074
# Epoch 251/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0071
# Epoch 252/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0070
# Epoch 253/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0065
# Epoch 254/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0071
# Epoch 255/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0068
# Epoch 256/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0081
# Epoch 257/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0077
# Epoch 258/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0080
# Epoch 259/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0062
# Epoch 260/400
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0071
# Epoch 261/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0081
# Epoch 262/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0073
# Epoch 263/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0074
# Epoch 264/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0075
# Epoch 265/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0080
# Epoch 266/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0065
# Epoch 267/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0079
# Epoch 268/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0066
# Epoch 269/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0070
# Epoch 270/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0073
# Epoch 271/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0074
# Epoch 272/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0066
# Epoch 273/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0064
# Epoch 274/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0065
# Epoch 275/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0066
# Epoch 276/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0073
# Epoch 277/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0064
# Epoch 278/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0073
# Epoch 279/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0068
# Epoch 280/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0068
# Epoch 281/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0071
# Epoch 282/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0062
# Epoch 283/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0070
# Epoch 284/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0066
# Epoch 285/400
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0067
# Epoch 286/400
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0061
# Epoch 287/400
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0064
# Epoch 288/400
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0075
# Epoch 289/400
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0071
# Epoch 290/400
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0076
# Epoch 291/400
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0064
# Epoch 292/400
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0068
# Epoch 293/400
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0068
# Epoch 294/400
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0069
# Epoch 295/400
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0069
# Epoch 296/400
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0064
# Epoch 297/400
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0071
# Epoch 298/400
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0063
# Epoch 299/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0071
# Epoch 300/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0072
# Epoch 301/400
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0072
# Epoch 302/400
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0062
# Epoch 303/400
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0065
# Epoch 304/400
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0066
# Epoch 305/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0062
# Epoch 306/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0065
# Epoch 307/400
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0068
# Epoch 308/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0064
# Epoch 309/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0069
# Epoch 310/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0060
# Epoch 311/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0060
# Epoch 312/400
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0067
# Epoch 313/400
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0064
# Epoch 314/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0062
# Epoch 315/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0071
# Epoch 316/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0064
# Epoch 317/400
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0068
# Epoch 318/400
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0071
# Epoch 319/400
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0077
# Epoch 320/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0066
# Epoch 321/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0062
# Epoch 322/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0079
# Epoch 323/400
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0060
# Epoch 324/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0058
# Epoch 325/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0068
# Epoch 326/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0061
# Epoch 327/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0059
# Epoch 328/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0076
# Epoch 329/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0063
# Epoch 330/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0064
# Epoch 331/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0059
# Epoch 332/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0065
# Epoch 333/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0057
# Epoch 334/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0055
# Epoch 335/400
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0064
# Epoch 336/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0060
# Epoch 337/400
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0062
# Epoch 338/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0062
# Epoch 339/400
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0067
# Epoch 340/400
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0065
# Epoch 341/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0055
# Epoch 342/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0068
# Epoch 343/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0057
# Epoch 344/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0063
# Epoch 345/400
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0061
# Epoch 346/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0073
# Epoch 347/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0061
# Epoch 348/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0055
# Epoch 349/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0063
# Epoch 350/400
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0067
# Epoch 351/400
# 4/4 [==============================] - 0s 118ms/step - loss: 0.0066
# Epoch 352/400
# 4/4 [==============================] - 0s 99ms/step - loss: 0.0060
# Epoch 353/400
# 4/4 [==============================] - 0s 93ms/step - loss: 0.0063
# Epoch 354/400
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0056
# Epoch 355/400
# 4/4 [==============================] - 0s 118ms/step - loss: 0.0059
# Epoch 356/400
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0059
# Epoch 357/400
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0057
# Epoch 358/400
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0061
# Epoch 359/400
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0057
# Epoch 360/400
# 4/4 [==============================] - 0s 91ms/step - loss: 0.0054
# Epoch 361/400
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0057
# Epoch 362/400
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0062
# Epoch 363/400
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0063
# Epoch 364/400
# 4/4 [==============================] - 0s 100ms/step - loss: 0.0060
# Epoch 365/400
# 4/4 [==============================] - 0s 90ms/step - loss: 0.0061
# Epoch 366/400
# 4/4 [==============================] - 1s 189ms/step - loss: 0.0058
# Epoch 367/400
# 4/4 [==============================] - 1s 149ms/step - loss: 0.0059
# Epoch 368/400
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0062
# Epoch 369/400
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0061
# Epoch 370/400
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0060
# Epoch 371/400
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0054
# Epoch 372/400
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0059
# Epoch 373/400
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0054
# Epoch 374/400
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0053
# Epoch 375/400
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0056
# Epoch 376/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0057
# Epoch 377/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0062
# Epoch 378/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0056
# Epoch 379/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0065
# Epoch 380/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0058
# Epoch 381/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0055
# Epoch 382/400
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0060
# Epoch 383/400
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0061
# Epoch 384/400
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0057
# Epoch 385/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0055
# Epoch 386/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0053
# Epoch 387/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0056
# Epoch 388/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0056
# Epoch 389/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0061
# Epoch 390/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0054
# Epoch 391/400
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0055
# Epoch 392/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0055
# Epoch 393/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0053
# Epoch 394/400
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0056
# Epoch 395/400
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0058
# Epoch 396/400
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0054
# Epoch 397/400
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0066
# Epoch 398/400
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0055
# Epoch 399/400
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0054
# Epoch 400/400
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0058

# %%
#가중치 저장
model.save_weights('LSTM_AVG_prd_weight_learnByAll.h5')

# %%
predictions = model.predict(_data_X)  # Replace 'test_data' with your actual test dataset

# Assuming predictions is a NumPy array
column_names = [f'Prediction_{i}' for i in range(predictions.shape[1])]
predictions_df = pd.DataFrame(predictions, columns=column_names)

# Save predictions to an Excel file
predictions_df.to_excel('model_predictions_learnedByAll.xlsx', index=False)
# Out:
# 8/8 [==============================] - 0s 11ms/step

# %%
import matplotlib.pyplot as plt

stocks = {
        'Tele' : ['VZ', 'DIS', 'T', 'CMCSA', 'EA'],
        'COND' : ['AMZN', 'HD', 'MCD', 'NKE', 'SBUX'],
        'ENRG': ['XOM', 'CVX', 'COP', 'EOG', 'SLB'],
        'HLCA' : ['JNJ', 'PFE', 'UNH','MRK','ABT'],
        'INDS' : ['BA', 'MMM','UNP','HON','RTX'],
        'MTRS': ['PPG', 'APD', 'ECL', 'SHW', 'NEM'],
        'FINC' : ['JPM', 'BRK-B', 'BAC', 'WFC', 'C'],
        'CONS' : ['PG', 'KO', 'PEP','WMT','MO'],
        'INFT' : ['AAPL','MSFT','INTC','CSCO','ORCL'],
        'UTIL' : ['NEE','DUK','D','SO','EXC'],
        'REES' : ['AMT', 'SPG', 'CCI', 'PLD', 'PSA']
    }


# 각 주식에 대한 그래프 그리기 위해 회사 리스트 생성
company_list = []
for sector in stocks:
    company_list += stocks[sector]

plt.rcParams['font.size'] = 20

# 각 주식 별 예측값&실제값 그래프 그리기
for i, company in enumerate(company_list):
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    plt.plot(_data_y[:,i], color='blue', label='Actual Stock Price of ' + company)

    # 예측 데이터 그래프
    plt.plot(predictions[:,i], color='red', label='Predicted Stock Price of ' + company)

    plt.title('Stock Price Prediction of ' + company)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 각 섹터별 예측값&실제값 그래프 그리기

plt.rcParams['font.size'] = 20

for sector in stocks:
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    avg_test_y = np.mean([_data_y[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_test_y, color='blue', label='Average Real Stock Price of ' + sector)

    # 예측 데이터 그래프
    avg_pred_y = np.mean([predictions[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price of ' + sector)

    plt.title('Average Stock Price Prediction of ' + sector, fontsize=36)
    plt.xlabel('Time', fontsize=36)
    plt.ylabel('Stock Price', fontsize=36)
    plt.legend()
    plt.show()

# %%
# 모든 주식의 평균 예측값& 실제값 그래프 그리기

plt.rcParams['font.size'] = 20

plt.figure(figsize=(20,10))

# 실제 데이터 그래프
avg_test_y = np.mean(_data_y, axis=1)
plt.plot(avg_test_y, color='blue', label='Average Real Stock Price')

# 예측 데이터 그래프
avg_pred_y = np.mean(predictions, axis=1)
plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price')

plt.title('Average Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
