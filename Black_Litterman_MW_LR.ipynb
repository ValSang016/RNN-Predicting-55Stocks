# %%
pip install PyPortfolioOpt
# Out:
# Collecting PyPortfolioOpt
#   Downloading pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 513.3 kB/s eta 0:00:00
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /usr/local/lib/python3.10/dist-packages (from PyPortfolioOpt) (1.3.2)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from PyPortfolioOpt) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from PyPortfolioOpt) (1.5.3)
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from PyPortfolioOpt) (1.11.4)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (3.2.4.post1)
# Requirement already satisfied: setuptools>65.5.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2023.3.post1)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.1.7.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# Installing collected packages: PyPortfolioOpt
# Successfully installed PyPortfolioOpt-1.5.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pandas import Timestamp
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import BlackLittermanModel, CovarianceShrinkage

from tensorflow.keras import Sequential
from keras.layers import Dense, GRU, Dropout
from tensorflow.keras.layers import LeakyReLU

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **데이터셋 생성 : 1.BL구성용 2.모델학습용**

# %%
## BL 포트폴리오 데이터셋 생성
# 데이터 병합
sectors_price_data = {}
excel_file_path1 = 'stocks_1999_2020_data_by_sector.xlsx'
price_data = pd.ExcelFile(excel_file_path1)
for sheet_name in price_data.sheet_names:
    sheet_data1 = pd.read_excel(excel_file_path1, sheet_name=sheet_name)
    sheet_data1['Date'] = pd.to_datetime(sheet_data1['Unnamed: 0'], format='%Y-%m-%d')
    sheet_data1.set_index('Date', inplace=True)
    sheet_data1.drop(columns='Unnamed: 0', inplace=True)
    sectors_price_data[sheet_name] = sheet_data1

# 데이터프레임 생성
price_df = pd.DataFrame()
for sector, data in sectors_price_data.items():
    data.columns = [f"{sector}_{col}" for col in data.columns]
    if price_df.empty:
        price_df = data
    else:
        price_df = price_df.join(data, how='outer')

# 로그수익률 생성
logReturn_df = np.log(price_df / price_df.shift(1))
logReturn_df = logReturn_df.dropna()

# %% [markdown]
# 모델 학습데이터 구성해야하는데, 일단 학습데이터를 구성해서 학습시키고, 테스트 데이터를 만들어서 뷰를 구성해야하는 테스트 데이터만드는 코드도 추가해야함.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

def generate_model_data(start_of_learn, test_start_date, invest_data):
    model_learning_data_X = []
    model_learning_data_y = []
    start_day_idx = [] # data_X를 생성하기 위한 매달 시작일 인덱스 리스트
    model_start_date = start_of_learn - pd.DateOffset(years=2) - pd.DateOffset(months=9)
    model_end_date = start_of_learn - pd.DateOffset(days=1)

    while model_start_date < model_end_date:
        end_of_model = model_start_date + pd.DateOffset(months=1) - pd.DateOffset(days=1)
        selected_data = logReturn_df[(logReturn_df.index >= model_start_date) & (logReturn_df.index <= end_of_model)]
        indexing = logReturn_df.index.get_loc(selected_data.index[0])

        # 각 주식에 대한 월별 평균 수익률 계산
        average_values = selected_data.mean(axis=0)

        model_learning_data_y.append(average_values)
        start_day_idx.append(indexing)
        model_start_date = model_start_date + pd.DateOffset(months=1)  # Move to next month

    i = 0
    while i < len(model_learning_data_y):
        index_day_start = start_day_idx[i]

        nearest_index = None
        for j in range(index_day_start, index_day_start - 60, -1):
            if j < 0:
                break
            if logReturn_df.index[j] in logReturn_df.index:
                nearest_index = j
                break

        if nearest_index is not None:
            sixty_day_data = logReturn_df.iloc[nearest_index - 60 : nearest_index]
            model_learning_data_X.append(sixty_day_data)
        else:
            pass

        i += 1
    idx = logReturn_df.index.get_loc(invest_data.index[0])
    model_testing_data_X = logReturn_df.iloc[idx-61:idx-1]
    model_testing_data_X = np.array(model_testing_data_X)

    return model_learning_data_X, model_learning_data_y, model_testing_data_X

def preprocessing_data(model_learning_data_X, model_learning_data_y, model_testing_data_X):
    # 전체 데이터 중 최소값과 최대값 구하기
    tot_train_min = np.minimum.reduce([np.min(model_learning_data_X), np.min(model_learning_data_y)])
    tot_train_max = np.maximum.reduce([np.max(model_learning_data_X), np.max(model_learning_data_y)])

    # 각 주식의 범위를 계산
    train_range = tot_train_max - tot_train_min

    # 스케일링
    L_scale_model_data_X = (model_learning_data_X - tot_train_min) / (train_range + 1e-7)
    L_scale_model_data_y = (model_learning_data_y - tot_train_min) / (train_range + 1e-7)
    T_scale_model_data_X = (model_testing_data_X - tot_train_min) / (train_range + 1e-7)

    # 각 행을 60번 반복 복붙
    L_scale_model_data_y = np.repeat(L_scale_model_data_y, repeats=60, axis=0)

    return L_scale_model_data_X, L_scale_model_data_y, T_scale_model_data_X, train_range, tot_train_min


def LR_model(L_scale_model_data_X, L_scale_model_data_y, T_scale_model_data_X, train_range, tot_train_min):

    predictions = []

    for i in range(55):  # 55개 주식에 대해 반복
      model = LinearRegression()
      # 각 주식에 대한 수익률을 종속 변수로 사용하여 모델 훈련
      train_X_reshaped = L_scale_model_data_X.reshape(-1, 55)
      model.fit(train_X_reshaped, L_scale_model_data_y[:, i])

      # 테스트 데이터로 예측
      test_X_reshaped = T_scale_model_data_X.reshape(-1, 55)
      prediction = model.predict(test_X_reshaped)
      predictions.append(prediction)

    print('훈련 데이터의 크기 :', train_X_reshaped.shape, L_scale_model_data_y.shape)
    print('테스트 데이터의 크기 :', test_X_reshaped.shape)

    predictions = np.array(predictions).T

    predictions_reshaped = predictions.reshape(-1, 60 ,55)
    predictions_means = predictions_reshaped.mean(axis=1)

    # Un-scailing
    _predictions = predictions_means * (train_range + 1e-7) + tot_train_min
    # __predictions = binarize_predictions(_predictions)
    return _predictions

def binarize_predictions(predictions):
    # 로그 수익률이 0보다 크면 그대로, 그렇지 않으면 하락(0)으로 판단
    binary_predictions = np.where(predictions > 0, predictions, 0)
    return binary_predictions

# %%
# 날짜 계산
test_start_date = pd.Timestamp('2002-04-01')
test_end_date = pd.Timestamp('2020-12-31')

# 누적 수익률 초기화
cumulative_returns = [0]

learn_data = []
invest_data = []
exception_indices = []
exception_values = []
exception_count = 0
zero_count = 0
i = 1


# 포트폴리오 최적화(블랙-리터만)과 리밸런싱
while test_start_date < test_end_date:
    exception_occurred = False  # 예외 발생 여부를 추적하기 위한 플래그
    monthly_indices = []  # 이번 달의 인덱스를 저장할 리스트

    print(test_start_date, i, '번째 학습')
    start_of_learn = test_start_date - pd.DateOffset(months=3)
    end_of_invest = test_start_date + pd.DateOffset(months=1) - pd.DateOffset(days=1)

    # BL PF 데이터셋 구성
    learn_data = price_df[(price_df.index >= start_of_learn) & (price_df.index < test_start_date)]
    invest_data = price_df[(price_df.index >= test_start_date) & (price_df.index <= end_of_invest)]
    invest_log_return = logReturn_df[(logReturn_df.index >= test_start_date) & (logReturn_df.index <= end_of_invest)]

    model_learning_data_X = []
    model_learning_data_y = []
    model_testing_data_X  = []
    L_scale_model_data_X  = []
    L_scale_model_data_y = []
    T_scale_model_data_X = []
    T_scale_model_data_y = []
    # 예측 모델 학습 Step1.테스트 학습데이터셋과 테스트데이터 생성
    model_learning_data_X, model_learning_data_y, model_testing_data_X = generate_model_data(start_of_learn, test_start_date, invest_data)
    # 예측 모델 학습 Step2.데이터 스케일링하기
    L_scale_model_data_X, L_scale_model_data_y, T_scale_model_data_X, train_range, tot_train_min = preprocessing_data(model_learning_data_X, model_learning_data_y, model_testing_data_X)
    # 예측 모델 학습 Step3.예측 돌리기
    Q = LR_model(L_scale_model_data_X, L_scale_model_data_y, T_scale_model_data_X, train_range, tot_train_min)

    # 수익률 예측값으로 P, Q 행렬 구성
    Q = np.array(Q).reshape(-1, 1)
    Q = Q.flatten()

    # if np.all(Q < 0):
    #   for _ in range(len(invest_data)):
    #     cumulative_returns.append(cumulative_returns[-1])
    #   test_start_date = test_start_date + pd.DateOffset(months=1)
    #   i += 1
    #   zero_count += 1
    #   print(len(cumulative_returns))
    #   print('PASS(All view is zero)')
    #   continue

    P = np.zeros((55, len(learn_data.columns)))

    for k in range(55):
      P[k,k] = 1

    # Omega 행렬
    omega = np.eye(55) * 0.01

    # 블랙리터만 뷰 설정 및 최적화
    S = CovarianceShrinkage(learn_data).ledoit_wolf()
    bl = BlackLittermanModel(S, P=P, Q=Q, omega=omega)
    ret_bl = bl.bl_returns()
    ef = EfficientFrontier(ret_bl, S)
    try:
      weights = ef.max_sharpe()
    except:
      print('except')
      weights = {}
      exception_occurred = True  # 예외 발생 플래그 설정
      exception_count += 1  # 예외 발생 횟수 증가
      for j in learn_data.columns:
        weights[j] = 1/55 # 1/n 씩 투자했다고 가정

    # 일별수익률
    portfolio_log_return = (invest_log_return * pd.Series(weights)).sum(axis=1)
    new_cumulative_return = 0  # 누적 로그 수익률 초기화

    # 이 달에 대한 누적 수익률을 계산
    for daily_return in portfolio_log_return.tolist():
        new_cumulative_return = cumulative_returns[-1] + daily_return
        cumulative_returns.append(new_cumulative_return)
        if exception_occurred:
            monthly_indices.append(len(cumulative_returns) - 1)

    # 예외가 발생했다면 이 달의 인덱스를 exception_indices에 추가
    if exception_occurred:
        exception_indices.extend(monthly_indices)
        exception_values.extend([cumulative_returns[idx] for idx in monthly_indices])

    # 다음 투자 기간으로 이동
    test_start_date = test_start_date + pd.DateOffset(months=1)
    i += 1

plt.rcParams['font.size'] = 20
plt.figure(figsize=(15, 7))
plt.plot(cumulative_returns, label='Cumulative Log Returns')

# 예외가 발생한 인덱스에 대해 다른 색상으로 점 표시
plt.scatter(exception_indices, exception_values, color='r', marker='o', label='Exceptions')

plt.grid(True)
plt.xlabel('Investment Period')
plt.ylabel('Cumulative Log Returns')
plt.title('Cumulative Log Returns over Time (Black-Litterman with LR)')
plt.show()

print(exception_count, "/", i-1)
print(zero_count, "/", i-1)
# Out:
# 2002-04-01 00:00:00 1 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2002-05-01 00:00:00 2 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2002-06-01 00:00:00 3 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2002-07-01 00:00:00 4 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2002-08-01 00:00:00 5 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2002-09-01 00:00:00 6 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2002-10-01 00:00:00 7 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2002-11-01 00:00:00 8 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2002-12-01 00:00:00 9 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-01-01 00:00:00 10 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-02-01 00:00:00 11 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-03-01 00:00:00 12 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-04-01 00:00:00 13 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-05-01 00:00:00 14 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-06-01 00:00:00 15 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-07-01 00:00:00 16 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-08-01 00:00:00 17 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-09-01 00:00:00 18 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-10-01 00:00:00 19 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-11-01 00:00:00 20 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2003-12-01 00:00:00 21 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-01-01 00:00:00 22 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-02-01 00:00:00 23 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-03-01 00:00:00 24 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-04-01 00:00:00 25 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-05-01 00:00:00 26 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-06-01 00:00:00 27 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-07-01 00:00:00 28 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-08-01 00:00:00 29 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-09-01 00:00:00 30 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-10-01 00:00:00 31 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-11-01 00:00:00 32 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2004-12-01 00:00:00 33 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-01-01 00:00:00 34 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-02-01 00:00:00 35 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-03-01 00:00:00 36 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-04-01 00:00:00 37 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-05-01 00:00:00 38 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-06-01 00:00:00 39 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-07-01 00:00:00 40 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-08-01 00:00:00 41 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-09-01 00:00:00 42 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-10-01 00:00:00 43 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-11-01 00:00:00 44 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2005-12-01 00:00:00 45 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-01-01 00:00:00 46 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-02-01 00:00:00 47 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-03-01 00:00:00 48 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-04-01 00:00:00 49 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-05-01 00:00:00 50 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-06-01 00:00:00 51 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-07-01 00:00:00 52 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-08-01 00:00:00 53 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-09-01 00:00:00 54 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-10-01 00:00:00 55 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-11-01 00:00:00 56 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2006-12-01 00:00:00 57 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-01-01 00:00:00 58 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-02-01 00:00:00 59 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-03-01 00:00:00 60 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-04-01 00:00:00 61 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-05-01 00:00:00 62 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-06-01 00:00:00 63 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-07-01 00:00:00 64 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-08-01 00:00:00 65 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-09-01 00:00:00 66 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-10-01 00:00:00 67 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-11-01 00:00:00 68 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2007-12-01 00:00:00 69 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-01-01 00:00:00 70 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-02-01 00:00:00 71 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-03-01 00:00:00 72 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-04-01 00:00:00 73 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-05-01 00:00:00 74 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-06-01 00:00:00 75 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-07-01 00:00:00 76 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-08-01 00:00:00 77 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-09-01 00:00:00 78 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-10-01 00:00:00 79 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-11-01 00:00:00 80 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2008-12-01 00:00:00 81 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-01-01 00:00:00 82 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-02-01 00:00:00 83 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-03-01 00:00:00 84 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-04-01 00:00:00 85 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-05-01 00:00:00 86 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-06-01 00:00:00 87 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-07-01 00:00:00 88 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-08-01 00:00:00 89 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-09-01 00:00:00 90 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-10-01 00:00:00 91 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-11-01 00:00:00 92 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2009-12-01 00:00:00 93 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-01-01 00:00:00 94 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-02-01 00:00:00 95 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-03-01 00:00:00 96 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-04-01 00:00:00 97 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-05-01 00:00:00 98 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-06-01 00:00:00 99 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-07-01 00:00:00 100 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-08-01 00:00:00 101 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-09-01 00:00:00 102 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-10-01 00:00:00 103 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-11-01 00:00:00 104 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2010-12-01 00:00:00 105 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-01-01 00:00:00 106 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-02-01 00:00:00 107 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-03-01 00:00:00 108 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-04-01 00:00:00 109 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-05-01 00:00:00 110 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-06-01 00:00:00 111 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-07-01 00:00:00 112 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-08-01 00:00:00 113 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-09-01 00:00:00 114 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-10-01 00:00:00 115 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-11-01 00:00:00 116 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2011-12-01 00:00:00 117 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-01-01 00:00:00 118 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-02-01 00:00:00 119 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-03-01 00:00:00 120 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-04-01 00:00:00 121 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-05-01 00:00:00 122 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-06-01 00:00:00 123 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-07-01 00:00:00 124 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-08-01 00:00:00 125 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-09-01 00:00:00 126 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-10-01 00:00:00 127 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-11-01 00:00:00 128 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2012-12-01 00:00:00 129 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-01-01 00:00:00 130 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-02-01 00:00:00 131 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-03-01 00:00:00 132 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-04-01 00:00:00 133 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-05-01 00:00:00 134 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-06-01 00:00:00 135 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-07-01 00:00:00 136 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-08-01 00:00:00 137 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-09-01 00:00:00 138 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-10-01 00:00:00 139 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-11-01 00:00:00 140 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2013-12-01 00:00:00 141 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-01-01 00:00:00 142 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-02-01 00:00:00 143 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-03-01 00:00:00 144 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-04-01 00:00:00 145 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-05-01 00:00:00 146 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-06-01 00:00:00 147 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-07-01 00:00:00 148 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-08-01 00:00:00 149 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-09-01 00:00:00 150 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-10-01 00:00:00 151 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-11-01 00:00:00 152 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2014-12-01 00:00:00 153 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-01-01 00:00:00 154 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-02-01 00:00:00 155 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-03-01 00:00:00 156 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-04-01 00:00:00 157 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-05-01 00:00:00 158 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-06-01 00:00:00 159 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-07-01 00:00:00 160 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-08-01 00:00:00 161 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-09-01 00:00:00 162 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-10-01 00:00:00 163 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-11-01 00:00:00 164 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2015-12-01 00:00:00 165 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-01-01 00:00:00 166 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-02-01 00:00:00 167 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-03-01 00:00:00 168 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-04-01 00:00:00 169 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-05-01 00:00:00 170 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-06-01 00:00:00 171 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-07-01 00:00:00 172 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-08-01 00:00:00 173 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-09-01 00:00:00 174 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-10-01 00:00:00 175 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-11-01 00:00:00 176 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2016-12-01 00:00:00 177 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-01-01 00:00:00 178 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-02-01 00:00:00 179 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-03-01 00:00:00 180 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-04-01 00:00:00 181 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-05-01 00:00:00 182 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-06-01 00:00:00 183 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-07-01 00:00:00 184 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-08-01 00:00:00 185 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-09-01 00:00:00 186 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-10-01 00:00:00 187 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-11-01 00:00:00 188 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2017-12-01 00:00:00 189 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-01-01 00:00:00 190 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-02-01 00:00:00 191 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-03-01 00:00:00 192 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-04-01 00:00:00 193 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-05-01 00:00:00 194 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-06-01 00:00:00 195 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-07-01 00:00:00 196 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-08-01 00:00:00 197 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-09-01 00:00:00 198 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-10-01 00:00:00 199 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-11-01 00:00:00 200 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2018-12-01 00:00:00 201 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-01-01 00:00:00 202 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-02-01 00:00:00 203 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-03-01 00:00:00 204 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-04-01 00:00:00 205 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-05-01 00:00:00 206 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-06-01 00:00:00 207 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-07-01 00:00:00 208 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-08-01 00:00:00 209 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-09-01 00:00:00 210 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-10-01 00:00:00 211 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-11-01 00:00:00 212 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2019-12-01 00:00:00 213 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-01-01 00:00:00 214 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-02-01 00:00:00 215 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-03-01 00:00:00 216 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-04-01 00:00:00 217 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-05-01 00:00:00 218 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-06-01 00:00:00 219 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-07-01 00:00:00 220 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-08-01 00:00:00 221 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-09-01 00:00:00 222 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-10-01 00:00:00 223 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-11-01 00:00:00 224 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 2020-12-01 00:00:00 225 번째 학습
# 훈련 데이터의 크기 : (1980, 55) (1980, 55)
# 테스트 데이터의 크기 : (60, 55)
# except
# 225 / 225
# 0 / 225

# %%
cumulative_returns[-1]
# Out:
# 1.8847205915599656

# %%
df = pd.DataFrame(cumulative_returns)
df.to_excel('cumulative_returns.xlsx')

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
kk = pd.DataFrame(cumulative_returns)
kk.to_excel('/content/gdrive/MyDrive/Colab Notebooks/ZeroZero_GRU_min_cumulative_returns.xlsx')
# Out:
# 0 / 225

# %%
print(exception_count, "/", i-1)
print(zero_count, "/", i-1)
# Out:
# 0 / 225
# 61 / 225

# %%
plt.rcParams['font.size'] = 20
plt.figure(figsize=(15, 7))
plt.plot(cumulative_returns, label='Cumulative Log Returns')

# 예외가 발생한 인덱스에 대해 다른 색상으로 점 표시
plt.scatter(exception_indices, exception_values, color='r', marker='o', label='Exceptions')

plt.grid(True)
plt.xlabel('Investment Period')
plt.ylabel('Cumulative Log Returns')
plt.title('Cumulative Log Returns over Time (Black-Litterman with LR)')
plt.show()

print(exception_count, "/", i-1)
print(zero_count, "/", i-1)
# Out:
# 0 / 225
# 0 / 225
