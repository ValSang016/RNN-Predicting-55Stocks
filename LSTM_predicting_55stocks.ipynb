# %%
import numpy as np
import pandas as pd

#데이터 불러오기
input_file = 'stocks_2000_2020_data_by_sector.xlsx'

all_price = []

# Excel 파일에 저장된 모든 시트 이름으로 불러오기
xls = pd.ExcelFile(input_file)
sheet_names = xls.sheet_names

# 모든 시트의 데이터를 하나의 데이터프레임으로 합치기
all_data = pd.concat([pd.read_excel(input_file, sheet_name=sheet, index_col=0) for sheet in sheet_names], axis=1)

# 날짜별 55개 주가데이터를 하나의 array로 형성
price_55 = all_data.values

# 결과 확인
print(price_55)
# Out:
# [[ 53.903156  29.471687  35.498489 ...  30.53125   19.8125    22.75    ]
#  [ 52.160721  31.198063  33.421452 ...  30.5       19.5       22.75    ]
#  [ 53.903156  32.492844  33.940708 ...  30.0625    19.25      22.9375  ]
#  ...
#  [ 58.98     178.860001  21.563444 ... 156.25      98.220001 229.139999]
#  [ 58.810001 177.300003  21.555891 ... 155.809998  97.720001 227.800003]
#  [ 58.139999 181.169998  21.518127 ... 156.389999  98.82     228.929993]]

# %%
#스케일링을 위한 학습데이터와 테스트데이터 셋 분리 -> 최대최소, 범위 계산
train_scaling_size = int(len(price_55) * 0.7)
t_train_X = np.array(price_55[0 : train_scaling_size])
t_train_y = np.array(price_55[0 : train_scaling_size])

# 전체 데이터 중 최소값과 최대값 구하기
tot_train_min = np.minimum.reduce([t_train_X.min(axis=0), t_train_y.min(axis=0)])
tot_train_max = np.maximum.reduce([t_train_X.max(axis=0), t_train_y.max(axis=0)])

# 각 주식의 범위를 계산
train_range = tot_train_max - tot_train_min

# %%
#60일씩 데이터 분리하여 사용 데이터 프레임 구성
window_size = 60

data_X = []
data_y = []
for i in range(len(price_55) - window_size):
    _X = price_55[i : i + window_size] # 다음 날 종가(i+windows_size)는 포함되지 않음
    _y = price_55[i + window_size]     # 다음 날 종가
    data_X.append(_X)
    data_y.append(_y)

# %%
#학습데이터와 테스트데이터 셋 분리
train_size = int(len(data_y) * 0.7)
train_X = np.array(data_X[0 : train_size])
train_y = np.array(data_y[0 : train_size])

test_size = len(data_y) - train_size
test_X = np.array(data_X[train_size : len(data_X)])
test_y = np.array(data_y[train_size : len(data_y)])

print('훈련 데이터의 크기 :', train_X.shape, train_y.shape)
print('테스트 데이터의 크기 :', test_X.shape, test_y.shape)
# Out:
# 훈련 데이터의 크기 : (3656, 60, 55) (3656, 55)
# 테스트 데이터의 크기 : (1567, 60, 55) (1567, 55)

# %%
# 스케일링
train_X = (train_X - tot_train_min) / (train_range + 1e-7)
train_y = (train_y - tot_train_min) / (train_range + 1e-7)
test_X = (test_X - tot_train_min) / (train_range + 1e-7)
test_y = (test_y - tot_train_min) / (train_range + 1e-7)

# %%
# 모델 준비 // 은닉층 개수, 활성화함수 결정
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

model = Sequential()
model.add(LSTM(units=20, activation='relu', return_sequences=True, input_shape=(60, 55)))
model.add(Dropout(0.1))
model.add(LSTM(units=20, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=55))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 20)            6080
#
#  dropout (Dropout)           (None, 60, 20)            0
#
#  lstm_1 (LSTM)               (None, 20)                3280
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense (Dense)               (None, 55)                1155
#
# =================================================================
# Total params: 10515 (41.07 KB)
# Trainable params: 10515 (41.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 옵티마이저와 손실함수 결정 및 학습 실행
model.compile(optimizer='adam', loss='mean_squared_error')

# model.load_weights('LSTM_55stocks_prd_weight.h5')

# %%
model.fit(train_X, train_y, epochs=200, batch_size=128)
# Out:
# Epoch 1/200
# 29/29 [==============================] - 5s 82ms/step - loss: 0.1678
# Epoch 2/200
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0784
# Epoch 3/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.0361
# Epoch 4/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0273
# Epoch 5/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0225
# Epoch 6/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0188
# Epoch 7/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0171
# Epoch 8/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0155
# Epoch 9/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.0142
# Epoch 10/200
# 29/29 [==============================] - 2s 86ms/step - loss: 0.0133
# Epoch 11/200
# 29/29 [==============================] - 4s 131ms/step - loss: 0.0126
# Epoch 12/200
# 29/29 [==============================] - 3s 114ms/step - loss: 0.0118
# Epoch 13/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.0112
# Epoch 14/200
# 29/29 [==============================] - 3s 95ms/step - loss: 0.0105
# Epoch 15/200
# 29/29 [==============================] - 2s 80ms/step - loss: 0.0102
# Epoch 16/200
# 29/29 [==============================] - 2s 62ms/step - loss: 0.0097
# Epoch 17/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0096
# Epoch 18/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0091
# Epoch 19/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0087
# Epoch 20/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0083
# Epoch 21/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0081
# Epoch 22/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0082
# Epoch 23/200
# 29/29 [==============================] - 2s 64ms/step - loss: 0.0080
# Epoch 24/200
# 29/29 [==============================] - 2s 79ms/step - loss: 0.0073
# Epoch 25/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.0075
# Epoch 26/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.0072
# Epoch 27/200
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0071
# Epoch 28/200
# 29/29 [==============================] - 3s 112ms/step - loss: 0.0070
# Epoch 29/200
# 29/29 [==============================] - 3s 84ms/step - loss: 0.0072
# Epoch 30/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.0069
# Epoch 31/200
# 29/29 [==============================] - 2s 80ms/step - loss: 0.0067
# Epoch 32/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.0068
# Epoch 33/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0066
# Epoch 34/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0065
# Epoch 35/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0065
# Epoch 36/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0063
# Epoch 37/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0064
# Epoch 38/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0062
# Epoch 39/200
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0062
# Epoch 40/200
# 29/29 [==============================] - 2s 80ms/step - loss: 0.0060
# Epoch 41/200
# 29/29 [==============================] - 2s 78ms/step - loss: 0.0062
# Epoch 42/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0061
# Epoch 43/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0058
# Epoch 44/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0058
# Epoch 45/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.0059
# Epoch 46/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.0057
# Epoch 47/200
# 29/29 [==============================] - 3s 114ms/step - loss: 0.0058
# Epoch 48/200
# 29/29 [==============================] - 2s 78ms/step - loss: 0.0057
# Epoch 49/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0056
# Epoch 50/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0055
# Epoch 51/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0054
# Epoch 52/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0054
# Epoch 53/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0055
# Epoch 54/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0053
# Epoch 55/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0053
# Epoch 56/200
# 29/29 [==============================] - 2s 81ms/step - loss: 0.0052
# Epoch 57/200
# 29/29 [==============================] - 2s 82ms/step - loss: 0.0052
# Epoch 58/200
# 29/29 [==============================] - 2s 51ms/step - loss: 0.0053
# Epoch 59/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0054
# Epoch 60/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0054
# Epoch 61/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0052
# Epoch 62/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0051
# Epoch 63/200
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0050
# Epoch 64/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.0050
# Epoch 65/200
# 29/29 [==============================] - 4s 130ms/step - loss: 0.0049
# Epoch 66/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0050
# Epoch 67/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0050
# Epoch 68/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0048
# Epoch 69/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0050
# Epoch 70/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0050
# Epoch 71/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0048
# Epoch 72/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0047
# Epoch 73/200
# 29/29 [==============================] - 2s 80ms/step - loss: 0.0049
# Epoch 74/200
# 29/29 [==============================] - 2s 81ms/step - loss: 0.0048
# Epoch 75/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0047
# Epoch 76/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0048
# Epoch 77/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0048
# Epoch 78/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0047
# Epoch 79/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0049
# Epoch 80/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0047
# Epoch 81/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0045
# Epoch 82/200
# 29/29 [==============================] - 4s 128ms/step - loss: 0.0047
# Epoch 83/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.0046
# Epoch 84/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0046
# Epoch 85/200
# 29/29 [==============================] - 2s 60ms/step - loss: 0.0045
# Epoch 86/200
# 29/29 [==============================] - 2s 82ms/step - loss: 0.0046
# Epoch 87/200
# 29/29 [==============================] - 2s 76ms/step - loss: 0.0044
# Epoch 88/200
# 29/29 [==============================] - 2s 60ms/step - loss: 0.0045
# Epoch 89/200
# 29/29 [==============================] - 2s 82ms/step - loss: 0.0047
# Epoch 90/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.0044
# Epoch 91/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.0044
# Epoch 92/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.0043
# Epoch 93/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.0046
# Epoch 94/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.0043
# Epoch 95/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.0045
# Epoch 96/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0046
# Epoch 97/200
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0046
# Epoch 98/200
# 29/29 [==============================] - 2s 81ms/step - loss: 0.0045
# Epoch 99/200
# 29/29 [==============================] - 2s 81ms/step - loss: 0.0043
# Epoch 100/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0045
# Epoch 101/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0043
# Epoch 102/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0043
# Epoch 103/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0042
# Epoch 104/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0043
# Epoch 105/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0044
# Epoch 106/200
# 29/29 [==============================] - 2s 65ms/step - loss: 0.0043
# Epoch 107/200
# 29/29 [==============================] - 2s 85ms/step - loss: 0.0044
# Epoch 108/200
# 29/29 [==============================] - 2s 74ms/step - loss: 0.0042
# Epoch 109/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0042
# Epoch 110/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0043
# Epoch 111/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0042
# Epoch 112/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0041
# Epoch 113/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0043
# Epoch 114/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0042
# Epoch 115/200
# 29/29 [==============================] - 2s 75ms/step - loss: 0.0042
# Epoch 116/200
# 29/29 [==============================] - 2s 81ms/step - loss: 0.0041
# Epoch 117/200
# 29/29 [==============================] - 2s 66ms/step - loss: 0.0042
# Epoch 118/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0042
# Epoch 119/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0042
# Epoch 120/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0042
# Epoch 121/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0042
# Epoch 122/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0040
# Epoch 123/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0041
# Epoch 124/200
# 29/29 [==============================] - 2s 83ms/step - loss: 0.0042
# Epoch 125/200
# 29/29 [==============================] - 3s 95ms/step - loss: 0.0043
# Epoch 126/200
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0043
# Epoch 127/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0042
# Epoch 128/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0041
# Epoch 129/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0040
# Epoch 130/200
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0041
# Epoch 131/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0040
# Epoch 132/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.0039
# Epoch 133/200
# 29/29 [==============================] - 2s 83ms/step - loss: 0.0042
# Epoch 134/200
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0041
# Epoch 135/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0040
# Epoch 136/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0040
# Epoch 137/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0040
# Epoch 138/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0042
# Epoch 139/200
# 29/29 [==============================] - 1s 52ms/step - loss: 0.0041
# Epoch 140/200
# 29/29 [==============================] - 2s 61ms/step - loss: 0.0042
# Epoch 141/200
# 29/29 [==============================] - 2s 74ms/step - loss: 0.0039
# Epoch 142/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0040
# Epoch 143/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0040
# Epoch 144/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0039
# Epoch 145/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0041
# Epoch 146/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0040
# Epoch 147/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0039
# Epoch 148/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.0040
# Epoch 149/200
# 29/29 [==============================] - 2s 65ms/step - loss: 0.0041
# Epoch 150/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0040
# Epoch 151/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0039
# Epoch 152/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0039
# Epoch 153/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0037
# Epoch 154/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0038
# Epoch 155/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0039
# Epoch 156/200
# 29/29 [==============================] - 2s 78ms/step - loss: 0.0039
# Epoch 157/200
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0040
# Epoch 158/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0038
# Epoch 159/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0038
# Epoch 160/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0041
# Epoch 161/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0039
# Epoch 162/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0038
# Epoch 163/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0039
# Epoch 164/200
# 29/29 [==============================] - 2s 80ms/step - loss: 0.0039
# Epoch 165/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0040
# Epoch 166/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0039
# Epoch 167/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0038
# Epoch 168/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0038
# Epoch 169/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0038
# Epoch 170/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0037
# Epoch 171/200
# 29/29 [==============================] - 2s 63ms/step - loss: 0.0037
# Epoch 172/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.0037
# Epoch 173/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0039
# Epoch 174/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0037
# Epoch 175/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0038
# Epoch 176/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0038
# Epoch 177/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0038
# Epoch 178/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0037
# Epoch 179/200
# 29/29 [==============================] - 2s 78ms/step - loss: 0.0036
# Epoch 180/200
# 29/29 [==============================] - 2s 59ms/step - loss: 0.0037
# Epoch 181/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0036
# Epoch 182/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0036
# Epoch 183/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0037
# Epoch 184/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0036
# Epoch 185/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0038
# Epoch 186/200
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0035
# Epoch 187/200
# 29/29 [==============================] - 2s 83ms/step - loss: 0.0037
# Epoch 188/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0037
# Epoch 189/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0036
# Epoch 190/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0036
# Epoch 191/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0037
# Epoch 192/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0038
# Epoch 193/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0037
# Epoch 194/200
# 29/29 [==============================] - 2s 62ms/step - loss: 0.0037
# Epoch 195/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.0037
# Epoch 196/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0037
# Epoch 197/200
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0036
# Epoch 198/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0036
# Epoch 199/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0037
# Epoch 200/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0037

# %%
#가중치 저장
model.save_weights('LSTM_55stocks_prd_weight.h5')

# %%
# 예측 결과 얻기
pred_y = model.predict(test_X)
# Out:
# 49/49 [==============================] - 1s 20ms/step

# %%
import matplotlib.pyplot as plt

stocks = {
        'Tele' : ['VZ', 'DIS', 'T', 'CMCSA', 'EA'],
        'COND' : ['AMZN', 'HD', 'MCD', 'NKE', 'SBUX'],
        'ENRG': ['XOM', 'CVX', 'COP', 'EOG', 'SLB'],
        'HLCA' : ['JNJ', 'PFE', 'UNH','MRK','ABT'],
        'INDS' : ['BA', 'MMM','UNP','HON','RTX'],
        'MTRS': ['PPG', 'APD', 'ECL', 'SHW', 'NEM'],
        'FINC' : ['JPM', 'BRK-B', 'BAC', 'WFC', 'C'],
        'CONS' : ['PG', 'KO', 'PEP','WMT','MO'],
        'INFT' : ['AAPL','MSFT','INTC','CSCO','ORCL'],
        'UTIL' : ['NEE','DUK','D','SO','EXC'],
        'REES' : ['AMT', 'SPG', 'CCI', 'PLD', 'PSA']
    }



# 각 주식에 대한 그래프 그리기 위해 회사 리스트 생성
company_list = []
for sector in stocks:
    company_list += stocks[sector]

plt.rcParams['font.size'] = 20

# 각 주식 별 예측값&실제값 그래프 그리기
for i, company in enumerate(company_list):
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    plt.plot(test_y[:,i], color='blue', label='Actual Stock Price of ' + company)

    # 예측 데이터 그래프
    plt.plot(pred_y[:,i], color='red', label='Predicted Stock Price of ' + company)

    plt.title('Stock Price Prediction of ' + company)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 각 섹터별 예측값&실제값 그래프 그리기

plt.rcParams['font.size'] = 20

for sector in stocks:
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    avg_test_y = np.mean([test_y[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_test_y, color='blue', label='Average Real Stock Price of ' + sector)

    # 예측 데이터 그래프
    avg_pred_y = np.mean([pred_y[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price of ' + sector)

    plt.title('Average Stock Price Prediction of ' + sector, fontsize=36)
    plt.xlabel('Time', fontsize=36)
    plt.ylabel('Stock Price', fontsize=36)
    plt.legend()
    plt.show()

# %%
# 모든 주식의 평균 예측값& 실제값 그래프 그리기

plt.rcParams['font.size'] = 20

plt.figure(figsize=(20,10))

# 실제 데이터 그래프
avg_test_y = np.mean(test_y, axis=1)
plt.plot(avg_test_y, color='blue', label='Average Real Stock Price')

# 예측 데이터 그래프
avg_pred_y = np.mean(pred_y, axis=1)
plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price')

plt.title('Average Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
