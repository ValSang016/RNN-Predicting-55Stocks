# %%
import numpy as np
import pandas as pd

sectors_data = {}
excel_file_path = 'stocks_2000_2020_data_by_sector.xlsx'
snp_price_data = pd.ExcelFile(excel_file_path)
for sheet_name in snp_price_data.sheet_names:
    sheet_data = pd.read_excel(excel_file_path, sheet_name=sheet_name)
    sheet_data['Date'] = pd.to_datetime(sheet_data['Unnamed: 0'], format='%Y-%m-%d')
    sheet_data.set_index('Date', inplace=True)
    sheet_data.drop(columns='Unnamed: 0', inplace=True)
    sectors_data[sheet_name] = sheet_data

# 데이터프레임 생성
df = pd.DataFrame()
for sector, data in sectors_data.items():
    data.columns = [f"{sector}_{col}" for col in data.columns]
    if df.empty:
        df = data
    else:
        df = df.join(data, how='outer')

# %%
#스케일링을 위한 학습데이터와 테스트데이터 셋 분리 -> 여기선 랜덤하게~~
t_train_X, _, t_train_y, __ = train_test_split(df, df, test_size=0.5, random_state=42)

t_train_X = np.array(t_train_X)
t_train_y = np.array(t_train_y)

# 전체 데이터 중 최소값과 최대값 구하기
tot_train_min = np.minimum.reduce([t_train_X.min(axis=0), t_train_y.min(axis=0)])
tot_train_max = np.maximum.reduce([t_train_X.max(axis=0), t_train_y.max(axis=0)])

# 각 주식의 범위를 계산
train_range = tot_train_max - tot_train_min

# %%
import pandas as pd

end_date = pd.Timestamp('2020-12-31')
one_month = pd.DateOffset(months=1)
sixty_days = pd.DateOffset(days=60)

data_X = []
data_y = []
start_day_idx = [] # data_X를 생성하기 위한 매달 시작일 인덱스 리스트

# data_y부터 생성
start_date = pd.Timestamp('2000-04-01')

while start_date < end_date:
    end_of_period = start_date + pd.DateOffset(months=1) - pd.DateOffset(days=1)
    selected_data = df[(df.index >= start_date) & (df.index <= end_of_period)]

    indexing = df.index.get_loc(selected_data.index[0])

    # 각 주식에 대한 월별 평균 수익률 계산
    average_values = selected_data.mean(axis=0)

    data_y.append(average_values)
    start_day_idx.append(indexing)
    start_date = start_date + pd.DateOffset(months=1)  # Move to next month

start_date = pd.Timestamp('2000-01-01')

i = 0
while i < len(data_y):
    index_day_start = start_day_idx[i]

    nearest_index = None
    for j in range(index_day_start - 1, index_day_start - 61, -1):
        if j < 0:
            break
        if df.index[j] in df.index:
            nearest_index = j
            break

    if nearest_index is not None:
        sixty_day_data = df.iloc[nearest_index - 60 : nearest_index]
        data_X.append(sixty_day_data)
    else:
        pass

    i += 1

# %%
from sklearn.model_selection import train_test_split

# Convert data_X and data_y to NumPy arrays
data_X_array = np.array(data_X)
data_y_array = np.array(data_y)

# Split data into training and testing sets (70% training, 30% testing)
train_X, test_X, train_y, test_y = train_test_split(data_X_array, data_y_array, test_size=0.5, random_state=42)

print('훈련 데이터의 크기 :', train_X.shape, train_y.shape)
print('테스트 데이터의 크기 :', test_X.shape, test_y.shape)
# Out:
# 훈련 데이터의 크기 : (124, 60, 55) (124, 55)
# 테스트 데이터의 크기 : (125, 60, 55) (125, 55)

# %%
# 스케일링
train_X = (train_X - tot_train_min) / (train_range + 1e-7)
train_y = (train_y - tot_train_min) / (train_range + 1e-7)
test_X = (data_X - tot_train_min) / (train_range + 1e-7)
test_y = (data_y - tot_train_min) / (train_range + 1e-7)

# %%
# 모델 준비 // 은닉층 개수, 활성화함수 결정
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

model = Sequential()
model.add(LSTM(units=20, activation='relu', return_sequences=True, input_shape=(60, 55)))
model.add(Dropout(0.1))
model.add(LSTM(units=20, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=55))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 60, 20)            6080
#
#  dropout_2 (Dropout)         (None, 60, 20)            0
#
#  lstm_3 (LSTM)               (None, 20)                3280
#
#  dropout_3 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 55)                1155
#
# =================================================================
# Total params: 10515 (41.07 KB)
# Trainable params: 10515 (41.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 옵티마이저와 손실함수 결정 및 학습 실행
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(train_X, train_y, epochs=400, batch_size=64)
# Out:
# Epoch 1/400
# 2/2 [==============================] - 4s 73ms/step - loss: 0.1892
# Epoch 2/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1828
# Epoch 3/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1776
# Epoch 4/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1722
# Epoch 5/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1659
# Epoch 6/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1583
# Epoch 7/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1493
# Epoch 8/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1473
# Epoch 9/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1388
# Epoch 10/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1343
# Epoch 11/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1293
# Epoch 12/400
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1229
# Epoch 13/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1181
# Epoch 14/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1150
# Epoch 15/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1070
# Epoch 16/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1033
# Epoch 17/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0985
# Epoch 18/400
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0943
# Epoch 19/400
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0880
# Epoch 20/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0840
# Epoch 21/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0775
# Epoch 22/400
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0729
# Epoch 23/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0734
# Epoch 24/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0659
# Epoch 25/400
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0663
# Epoch 26/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0599
# Epoch 27/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0573
# Epoch 28/400
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0545
# Epoch 29/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0515
# Epoch 30/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0494
# Epoch 31/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0486
# Epoch 32/400
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0450
# Epoch 33/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0440
# Epoch 34/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0447
# Epoch 35/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0409
# Epoch 36/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0369
# Epoch 37/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0384
# Epoch 38/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0404
# Epoch 39/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0387
# Epoch 40/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0374
# Epoch 41/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0351
# Epoch 42/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0362
# Epoch 43/400
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0356
# Epoch 44/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0357
# Epoch 45/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0320
# Epoch 46/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0307
# Epoch 47/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0321
# Epoch 48/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0339
# Epoch 49/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0318
# Epoch 50/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0299
# Epoch 51/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0287
# Epoch 52/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0327
# Epoch 53/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0317
# Epoch 54/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0288
# Epoch 55/400
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0287
# Epoch 56/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0269
# Epoch 57/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0285
# Epoch 58/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0292
# Epoch 59/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0293
# Epoch 60/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0288
# Epoch 61/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0285
# Epoch 62/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0268
# Epoch 63/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0258
# Epoch 64/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0266
# Epoch 65/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0262
# Epoch 66/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0259
# Epoch 67/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0265
# Epoch 68/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0250
# Epoch 69/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0251
# Epoch 70/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0264
# Epoch 71/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0253
# Epoch 72/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0242
# Epoch 73/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0253
# Epoch 74/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0238
# Epoch 75/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0232
# Epoch 76/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0233
# Epoch 77/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.
400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0099
# Epoch 190/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0107
# Epoch 191/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0098
# Epoch 192/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0095
# Epoch 193/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0102
# Epoch 194/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0088
# Epoch 195/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0088
# Epoch 196/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0087
# Epoch 197/400
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0093
# Epoch 198/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0093
# Epoch 199/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0093
# Epoch 200/400
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0089
# Epoch 201/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0096
# Epoch 202/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0095
# Epoch 203/400
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0098
# Epoch 204/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0092
# Epoch 205/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0085
# Epoch 206/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0094
# Epoch 207/400
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0091
# Epoch 208/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0089
# Epoch 209/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0090
# Epoch 210/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0084
# Epoch 211/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0093
# Epoch 212/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0092
# Epoch 213/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0091
# Epoch 214/400
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0093
# Epoch 215/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0100
# Epoch 216/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0104
# Epoch 217/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0093
# Epoch 218/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0080
# Epoch 219/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0095
# Epoch 220/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0084
# Epoch 221/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0087
# Epoch 222/400
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0091
# Epoch 223/400
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0091
# Epoch 224/400
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0090
# Epoch 225/400
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0092
# Epoch 226/400
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0106
# Epoch 227/400
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0085
# Epoch 228/400
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0089
# Epoch 229/400
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0093
# Epoch 230/400
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0091
# Epoch 231/400
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0086
# Epoch 232/400
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0093
# Epoch 233/400
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0094
# Epoch 234/400
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0081
# Epoch 235/400
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0091
# Epoch 236/400
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0101
# Epoch 237/400
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0075
# Epoch 238/400
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0084
# Epoch 239/400
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0094
# Epoch 240/400
# 2/2 [==============================] - 0s 89ms/step - loss: 0.0086
# Epoch 241/400
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0090
# Epoch 242/400
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0075
# Epoch 243/400
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0083
# Epoch 244/400
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0080
# Epoch 245/400
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0086
# Epoch 246/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0082
# Epoch 247/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0091
# Epoch 248/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0087
# Epoch 249/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0078
# Epoch 250/400
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0088
# Epoch 251/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0077
# Epoch 252/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0093
# Epoch 253/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0074
# Epoch 254/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0082
# Epoch 255/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0078
# Epoch 256/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0109
# Epoch 257/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0082
# Epoch 258/400
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0078
# Epoch 259/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0077
# Epoch 260/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0083
# Epoch 261/400
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0075
# Epoch 262/400
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0080
# Epoch 263/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0092
# Epoch 264/400
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0074
# Epoch 265/400
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0080
# Epoch 266/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0078
# Epoch 267/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0081
# Epoch 268/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0083
# Epoch 269/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0083
# Epoch 270/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0076
# Epoch 271/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0079
# Epoch 272/400
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0081
# Epoch 273/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0078
# Epoch 274/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0089
# Epoch 275/400
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0079
# Epoch 276/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0085
# Epoch 277/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0071
# Epoch 278/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0067
# Epoch 279/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0073
# Epoch 280/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0067
# Epoch 281/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0083
# Epoch 282/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0074
# Epoch 283/400
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0068
# Epoch 284/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0080
# Epoch 285/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0086
# Epoch 286/400
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0071
# Epoch 287/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0073
# Epoch 288/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0084
# Epoch 289/400
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0073
# Epoch 290/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0076
# Epoch 291/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0071
# Epoch 292/400
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0075
# Epoch 293/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0075
# Epoch 294/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0068
# Epoch 295/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0077
# Epoch 296/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0080
# Epoch 297/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0072
# Epoch 298/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.
400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0062

# %%
#가중치 저장
model.save_weights('LSTM_prd_weight_learnedByRandom50.h5')

# %%
predictions = model.predict(test_X)  # Replace 'test_data' with your actual test dataset

# Assuming predictions is a NumPy array
column_names = [f'Prediction_{i}' for i in range(predictions.shape[1])]
predictions_df = pd.DataFrame(predictions, columns=column_names)

# Save predictions to an Excel file
predictions_df.to_excel('model_predictions_learnedByRandom50.xlsx', index=False)
# Out:
# 8/8 [==============================] - 0s 30ms/step

# %%
import matplotlib.pyplot as plt

stocks = {
        'Tele' : ['VZ', 'DIS', 'T', 'CMCSA', 'EA'],
        'COND' : ['AMZN', 'HD', 'MCD', 'NKE', 'SBUX'],
        'ENRG': ['XOM', 'CVX', 'COP', 'EOG', 'SLB'],
        'HLCA' : ['JNJ', 'PFE', 'UNH','MRK','ABT'],
        'INDS' : ['BA', 'MMM','UNP','HON','RTX'],
        'MTRS': ['PPG', 'APD', 'ECL', 'SHW', 'NEM'],
        'FINC' : ['JPM', 'BRK-B', 'BAC', 'WFC', 'C'],
        'CONS' : ['PG', 'KO', 'PEP','WMT','MO'],
        'INFT' : ['AAPL','MSFT','INTC','CSCO','ORCL'],
        'UTIL' : ['NEE','DUK','D','SO','EXC'],
        'REES' : ['AMT', 'SPG', 'CCI', 'PLD', 'PSA']
    }


# 각 주식에 대한 그래프 그리기 위해 회사 리스트 생성
company_list = []
for sector in stocks:
    company_list += stocks[sector]

plt.rcParams['font.size'] = 20

# 각 주식 별 예측값&실제값 그래프 그리기
for i, company in enumerate(company_list):
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    plt.plot(test_y[:,i], color='blue', label='Actual Stock Price of ' + company)

    # 예측 데이터 그래프
    plt.plot(predictions[:,i], color='red', label='Predicted Stock Price of ' + company)

    plt.title('Stock Price Prediction of ' + company)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 각 섹터별 예측값&실제값 그래프 그리기

plt.rcParams['font.size'] = 20

for sector in stocks:
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    avg_test_y = np.mean([test_y[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_test_y, color='blue', label='Average Real Stock Price of ' + sector)

    # 예측 데이터 그래프
    avg_pred_y = np.mean([predictions[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price of ' + sector)

    plt.title('Average Stock Price Prediction of ' + sector, fontsize=36)
    plt.xlabel('Time', fontsize=36)
    plt.ylabel('Stock Price', fontsize=36)
    plt.legend()
    plt.show()

# %%
# 모든 주식의 평균 예측값& 실제값 그래프 그리기

plt.rcParams['font.size'] = 20

plt.figure(figsize=(20,10))

# 실제 데이터 그래프
avg_test_y = np.mean(test_y, axis=1)
plt.plot(avg_test_y, color='blue', label='Average Real Stock Price')

# 예측 데이터 그래프
avg_pred_y = np.mean(predictions, axis=1)
plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price')

plt.title('Average Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
