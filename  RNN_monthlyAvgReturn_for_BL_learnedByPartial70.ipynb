# %%
import numpy as np
import pandas as pd

sectors_data = {}
excel_file_path = 'stocks_2000_2020_data_by_sector.xlsx'
snp_price_data = pd.ExcelFile(excel_file_path)
for sheet_name in snp_price_data.sheet_names:
    sheet_data = pd.read_excel(excel_file_path, sheet_name=sheet_name)
    sheet_data['Date'] = pd.to_datetime(sheet_data['Unnamed: 0'], format='%Y-%m-%d')
    sheet_data.set_index('Date', inplace=True)
    sheet_data.drop(columns='Unnamed: 0', inplace=True)
    sectors_data[sheet_name] = sheet_data

# 데이터프레임 생성
df = pd.DataFrame()
for sector, data in sectors_data.items():
    data.columns = [f"{sector}_{col}" for col in data.columns]
    if df.empty:
        df = data
    else:
        df = df.join(data, how='outer')

# %%
#스케일링을 위한 학습데이터와 테스트데이터 셋 분리
train_scaling_size = int(len(df) * 0.7)
t_train_X = df[0 : train_scaling_size]
t_train_y = df[0 : train_scaling_size]


# 전체 데이터 중 최소값과 최대값 구하기
tot_train_min = np.minimum.reduce([t_train_X.min(axis=0), t_train_y.min(axis=0)])
tot_train_max = np.maximum.reduce([t_train_X.max(axis=0), t_train_y.max(axis=0)])

# 각 주식의 범위를 계산
train_range = tot_train_max - tot_train_min

# %%
import pandas as pd

end_date = pd.Timestamp('2020-12-31')
one_month = pd.DateOffset(months=1)
sixty_days = pd.DateOffset(days=60)

data_X = []
data_y = []
start_day_idx = [] # data_X를 생성하기 위한 매달 시작일 인덱스 리스트

# data_y부터 생성
start_date = pd.Timestamp('2000-04-01')

while start_date < end_date:
    end_of_period = start_date + pd.DateOffset(months=1) - pd.DateOffset(days=1)
    selected_data = df[(df.index >= start_date) & (df.index <= end_of_period)]

    indexing = df.index.get_loc(selected_data.index[0])

    # 각 주식에 대한 월별 평균 수익률 계산
    average_values = selected_data.mean(axis=0)

    data_y.append(average_values)
    start_day_idx.append(indexing)
    start_date = start_date + pd.DateOffset(months=1)  # Move to next month

i = 0
while i < len(data_y):
    index_day_start = start_day_idx[i]

    nearest_index = None
    for j in range(index_day_start, index_day_start - 60, -1):
        if j < 0:
            break
        if df.index[j] in df.index:
            nearest_index = j
            break

    if nearest_index is not None:
        sixty_day_data = df.iloc[nearest_index - 60 : nearest_index]
        data_X.append(sixty_day_data)
    else:
        pass

    i += 1

# %%
#학습데이터와 테스트데이터 셋 분리
train_size = int(len(data_y) * 0.7)
train_X = np.array(data_X[0 : train_size])
train_y = np.array(data_y[0 : train_size])

#테스트데이터는 전체 데이터로~
test_X = np.array(data_X)
test_y = np.array(data_y)

print('훈련 데이터의 크기 :', train_X.shape, train_y.shape)
print('테스트 데이터의 크기 :', test_X.shape, test_y.shape)
# Out:
# 훈련 데이터의 크기 : (174, 60, 55) (174, 55)
# 테스트 데이터의 크기 : (249, 60, 55) (249, 55)

# %%
# 스케일링
train_X = (train_X - tot_train_min) / (train_range + 1e-7)
train_y = (train_y - tot_train_min) / (train_range + 1e-7)
test_X = (test_X - tot_train_min) / (train_range + 1e-7)
test_y = (test_y - tot_train_min) / (train_range + 1e-7)

# %%
# 모델 준비 // 은닉층 개수, 활성화함수 결정
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

model = Sequential()
model.add(LSTM(units=20, activation='relu', return_sequences=True, input_shape=(60, 55)))
model.add(Dropout(0.1))
model.add(LSTM(units=20, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=55))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 20)            6080
#
#  dropout (Dropout)           (None, 60, 20)            0
#
#  lstm_1 (LSTM)               (None, 20)                3280
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense (Dense)               (None, 55)                1155
#
# =================================================================
# Total params: 10515 (41.07 KB)
# Trainable params: 10515 (41.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 옵티마이저와 손실함수 결정 및 학습 실행
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(train_X, train_y, epochs=400, batch_size=64)
# Out:
# Epoch 1/400
# 3/3 [==============================] - 4s 71ms/step - loss: 0.1991
# Epoch 2/400
# 3/3 [==============================] - 0s 56ms/step - loss: 0.1913
# Epoch 3/400
# 3/3 [==============================] - 0s 50ms/step - loss: 0.1828
# Epoch 4/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1715
# Epoch 5/400
# 3/3 [==============================] - 0s 89ms/step - loss: 0.1578
# Epoch 6/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1454
# Epoch 7/400
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1316
# Epoch 8/400
# 3/3 [==============================] - 0s 48ms/step - loss: 0.1213
# Epoch 9/400
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1138
# Epoch 10/400
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1030
# Epoch 11/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0938
# Epoch 12/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0854
# Epoch 13/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0787
# Epoch 14/400
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0730
# Epoch 15/400
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0649
# Epoch 16/400
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0597
# Epoch 17/400
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0544
# Epoch 18/400
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0501
# Epoch 19/400
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0451
# Epoch 20/400
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0434
# Epoch 21/400
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0408
# Epoch 22/400
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0403
# Epoch 23/400
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0381
# Epoch 24/400
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0371
# Epoch 25/400
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0349
# Epoch 26/400
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0349
# Epoch 27/400
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0338
# Epoch 28/400
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0348
# Epoch 29/400
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0309
# Epoch 30/400
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0316
# Epoch 31/400
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0299
# Epoch 32/400
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0292
# Epoch 33/400
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0280
# Epoch 34/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0275
# Epoch 35/400
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0270
# Epoch 36/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0274
# Epoch 37/400
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0272
# Epoch 38/400
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0246
# Epoch 39/400
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0256
# Epoch 40/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0238
# Epoch 41/400
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0249
# Epoch 42/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0249
# Epoch 43/400
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0236
# Epoch 44/400
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0238
# Epoch 45/400
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0220
# Epoch 46/400
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0228
# Epoch 47/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0232
# Epoch 48/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0233
# Epoch 49/400
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0211
# Epoch 50/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0218
# Epoch 51/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0214
# Epoch 52/400
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0218
# Epoch 53/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0206
# Epoch 54/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0208
# Epoch 55/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0206
# Epoch 56/400
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0199
# Epoch 57/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0207
# Epoch 58/400
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0194
# Epoch 59/400
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0189
# Epoch 60/400
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0198
# Epoch 61/400
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0186
# Epoch 62/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0186
# Epoch 63/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0190
# Epoch 64/400
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0176
# Epoch 65/400
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0176
# Epoch 66/400
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0181
# Epoch 67/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0189
# Epoch 68/400
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0184
# Epoch 69/400
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0173
# Epoch 70/400
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0174
# Epoch 71/400
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0173
# Epoch 72/400
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0173
# Epoch 73/400
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0161
# Epoch 74/400
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0159
# Epoch 75/400
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0167
# Epoch 76/400
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0166
# Epoch 77/400
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0158
# Epoch 78/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0171
# Epoch 79/400
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0151
# Epoch 80/400
# 3/3 [==============================] - 0s 88ms/step - loss: 0.
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0051

# %%
#가중치 저장
model.save_weights('LSTM_prd_weight_learnedByPartial70.h5')

# %%
predictions = model.predict(test_X)  # Replace 'test_data' with your actual test dataset

# Assuming predictions is a NumPy array
column_names = [f'Prediction_{i}' for i in range(predictions.shape[1])]
predictions_df = pd.DataFrame(predictions, columns=column_names)

# Save predictions to an Excel file
predictions_df.to_excel('model_predictions_learnedByPartial70.xlsx', index=False)
# Out:
# 8/8 [==============================] - 0s 13ms/step

# %%
import matplotlib.pyplot as plt

stocks = {
        'Tele' : ['VZ', 'DIS', 'T', 'CMCSA', 'EA'],
        'COND' : ['AMZN', 'HD', 'MCD', 'NKE', 'SBUX'],
        'ENRG': ['XOM', 'CVX', 'COP', 'EOG', 'SLB'],
        'HLCA' : ['JNJ', 'PFE', 'UNH','MRK','ABT'],
        'INDS' : ['BA', 'MMM','UNP','HON','RTX'],
        'MTRS': ['PPG', 'APD', 'ECL', 'SHW', 'NEM'],
        'FINC' : ['JPM', 'BRK-B', 'BAC', 'WFC', 'C'],
        'CONS' : ['PG', 'KO', 'PEP','WMT','MO'],
        'INFT' : ['AAPL','MSFT','INTC','CSCO','ORCL'],
        'UTIL' : ['NEE','DUK','D','SO','EXC'],
        'REES' : ['AMT', 'SPG', 'CCI', 'PLD', 'PSA']
    }


# 각 주식에 대한 그래프 그리기 위해 회사 리스트 생성
company_list = []
for sector in stocks:
    company_list += stocks[sector]

plt.rcParams['font.size'] = 20

# 각 주식 별 예측값&실제값 그래프 그리기
for i, company in enumerate(company_list):
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    plt.plot(test_y[:,i], color='blue', label='Actual Stock Price of ' + company)

    # 예측 데이터 그래프
    plt.plot(predictions[:,i], color='red', label='Predicted Stock Price of ' + company)

    plt.title('Stock Price Prediction of ' + company)
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 각 섹터별 예측값&실제값 그래프 그리기

plt.rcParams['font.size'] = 20

for sector in stocks:
    plt.figure(figsize=(20,10))

    # 실제 데이터 그래프
    avg_test_y = np.mean([test_y[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_test_y, color='blue', label='Average Real Stock Price of ' + sector)

    # 예측 데이터 그래프
    avg_pred_y = np.mean([predictions[:, company_list.index(company)] for company in stocks[sector]], axis=0)
    plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price of ' + sector)

    plt.title('Average Stock Price Prediction of ' + sector, fontsize=36)
    plt.xlabel('Time', fontsize=36)
    plt.ylabel('Stock Price', fontsize=36)
    plt.legend()
    plt.show()

# %%
# 모든 주식의 평균 예측값& 실제값 그래프 그리기

plt.rcParams['font.size'] = 20

plt.figure(figsize=(20,10))

# 실제 데이터 그래프
avg_test_y = np.mean(test_y, axis=1)
plt.plot(avg_test_y, color='blue', label='Average Real Stock Price')

# 예측 데이터 그래프
avg_pred_y = np.mean(predictions, axis=1)
plt.plot(avg_pred_y, color='red', label='Average Predicted Stock Price')

plt.title('Average Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
